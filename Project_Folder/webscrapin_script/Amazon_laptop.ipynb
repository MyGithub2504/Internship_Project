# %%
# importing necessary packages
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import WebDriverException
import selenium
import pandas as pd
import time
import warnings
import os
from time import sleep
warnings.filterwarnings("ignore")

# %%
# for holding the resultant list
Ratings1=[]
Review1=[]
url1=[]

# %%
#Lets first connect to the web driver
driver = webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
driver.get("https://www.amazon.in/")

# %%
search_field=driver.find_element_by_xpath("//input[@id='twotabsearchtextbox']")
search_field.send_keys("laptops")

# %%
search_btn=driver.find_element_by_xpath("//input[@id='nav-search-submit-button']")
search_btn.click()

# %% [markdown]
# ### Scrape url from Amazon

# %%
try:
    for i in range(50):
        for j in driver.find_elements_by_xpath("//a[@target='_blank']"):
            url1.append(j.get_attribute("href"))
        next_button=driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']")
        next_button.click()
        sleep(6)
except(NoSuchElementException, WebDriverException, TimeoutException):
    pass

# %%
len(url1)
# Out:
# 531

# %%
for i in url1:
    driver.get(i)
    time.sleep(3)
     #Fetching brand
    try:
        rating1=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")
        Ratings1.append(rating1.text.replace("/n","new line"))
    except (NoSuchElementException, WebDriverException, TimeoutException):
        pass
     #Fetching variant
    try:
        review1=driver.find_element_by_xpath("//div[@class='a-expander-content reviewText review-text-content a-expander-partial-collapse-content']")
        Review1.append(review1.text.replace("/n","new line"))
    except (NoSuchElementException, WebDriverException, TimeoutException):
        pass

# %%
Ratings1
# Out:
# ['4.4 out of 5',
#  '4.4 out of 5',
#  '4.4 out of 5',
#  '4.4 out of 5',
#  '3.7 out of 5',
#  '3.7 out of 5',
#  '3.7 out of 5',
#  '3.7 out of 5',
#  '3 out of 5',
#  '3 out of 5',
#  '3 out of 5',
#  '3 out of 5',
#  '3.7 out of 5',
#  '3.7 out of 5',
#  '3.7 out of 5',
#  '3.7 out of 5',
#  '4.1 out of 5',
#  '4.1 out of 5',
#  '4.1 out of 5',
#  '4.1 out of 5',
#  '4.1 out of 5',
#  '4.1 out of 5',
#  '4.1 out of 5',
#  '4.1 out of 5',
#  '4.2 out of 5',
#  '4.2 out of 5',
#  '4.2 out of 5',
#  '4.2 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '4.1 out of 5',
#  '4.1 out of 5',
#  '4.1 out of 5',
#  '4.1 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.7 out of 5',
#  '3.7 out of 5',
#  '3.7 out of 5',
#  '3.7 out of 5',
#  '3.7 out of 5',
#  '3.7 out of 5',
#  '3.7 out of 5',
#  '3.7 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4.3 out of 5',
# ...

# %%
Review1
# Out:
# ['Very Thin, light weight, fast boot, fast shut down. Longer battery life. You will love watching full HD or 4K videos on this display.\n\nAs I used for 2 days, so yet to validate battery strength on regular basis. I will share battery review after 1 week.\n16GB Ram, L3 8MB, 6 core Ryzen 5, NVME, good finger print lock.\nDelivered next day by Amazon.\n\nKeyboard gives initial impact that keys lettersnew lineumbers could be bolder. But with continued use you may find it comfortable. I think silver background and light black text may gives illusion of thin text on keys. It might be due to my use of complete black body laptop with white text keys earlier. But not big deal.\n\nSoftware is Win Home provided. Anti virus provided is McAfee which is one month free version. It could have been 1 year. Dropbox 12 month provided free, it could have been 1 month instead of McAfee. MS Office provided is desktop version. Office 365 is not included.\n\nI will recommend better you order laptop cushio
# ...

# %%
Laptops=pd.DataFrame({})
Laptops['Ratings']=Ratings1[0:342]
Laptops['Reviews']=Review1[0:342]
Laptops
# Out:
#           Ratings                                            Reviews
# 0    4.4 out of 5  Very Thin, light weight, fast boot, fast shut ...
# 1    4.4 out of 5  Very Thin, light weight, fast boot, fast shut ...
# 2    4.4 out of 5  Very Thin, light weight, fast boot, fast shut ...
# 3    4.4 out of 5  Very Thin, light weight, fast boot, fast shut ...
# 4    3.7 out of 5  After my 13inch MacBook I have tried several w...
# ..            ...                                                ...
# 337  3.8 out of 5  PROS:\n1- Best keyboard in the segment. (No Ba...
# 338  3.8 out of 5  PROS:\n1- Best keyboard in the segment. (No Ba...
# 339  4.5 out of 5  This is the first time i'm writing review for ...
# 340  4.5 out of 5  This is the first time i'm writing review for ...
# 341  4.5 out of 5  This is the first time i'm writing review for ...
#
# [342 rows x 2 columns]

# %%
Laptops.to_csv('Laptops_Amazon')
